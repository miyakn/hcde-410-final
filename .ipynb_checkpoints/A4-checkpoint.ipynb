# %% [markdown]
# # **Investigating the Relationship Between Social Media and Consumer Behavior**
#
# # Introduction
# ### Motivation and Problem Statement
# In recent years, social media has become a powerful tool in modern marketing to shape consumer behavior with the rising prevalence of influencers, targeted advertisements, and user-generated content on the platforms. I plan on analyzing social media’s influence on consumer spending habits and how these impacts may vary across different demographic groups.
#
# This research may help to better understand the psychology behind consumer choices in our digital age which would be useful in a practical sense for businesses and marketers to optimize online marketing strategies. From a human-centered perspective, this analysis can provide insights into how digital environments shape consumer choices, contributing to the conversation of how to design more user-centered marketing practices that consider the well-being of consumers.
#
# I hope to learn more about the connections and patterns between consumers and social media stimuli, and identify key factors that drive spending decisions. I also hope this analysis helps in providing a clearer understanding of the complex dynamics between social media engagement and financial decision-making.
#
# # Data Selected for Analysis
# [<u>Impact of Social Media (Dataset)</u>](https://www.kaggle.com/datasets/lastman0800/impact-of-social-media-dataset)
# * Summary of Data: This dataset is designed to capture various attributes of consumers, including their demographics (age, gender, income, city, education level), social media behavior (usage per day, platforms used, and level of influence), purchasing preferences (product category, brand, amount spend in USD), and the impact of social media on their decision-making process.
# * Why I’m Using It: This dataset would be helpful in identifying what demographic groups tended to be most influenced by social media in their spending decisions. For example, I can look into how the level of social media presence may influence the amount spent during a purchase..
# * License: “It can be used for various analyses and studies related to consumer behavior and marketing strategies in the context of social media influence” (note: there was no specific license listed, the only form of licensing was mentioned was in the description of the data, which is quoted here).
#
# # Unknowns and Dependencies
# A factor outside of my control that might impact my ability to complete this project by the end of the quarter is if social media actual does has a statistically significant influence on consumer buying behavior or not.

# %% [markdown]
# # Overview and Research Questions
# The goal of this project is to investigate the relationship between social media and consumer behavior by identifying factors that influence spending decisions and what demographics that influence is strongest with.
#
# Research Questions (in no particular order):
# 1. What demographic factors (age, gender, income, education level) have the strongest relationship with a consumer's purchase being influenced by social media?
# 2. Does the amount of social media platforms a consumer uses impact their spending habits?
# 3. Are there specific product categories where consumers are most likely to report that social media influenced their purchasing decisions?

# %% [markdown]
# # Background and Related Work
# Previous research has been performed to investigate the influence of social media on consumer behavior, many of which have reported at least some level of correlation (moderate to strong). Much of this research has been through a marketing lens. Some of this research focused on using social media to predict consumer spending instead of how social media influences spending. For example, research has found how social media data can be a powerful tool in forecasting consumer behavior by identifying purchase intentions expressed in social media posts. [[1](https://publications.aston.ac.uk/id/eprint/38890/1/W17_5212.pdf), [2](https://ojs.aaai.org/index.php/ICWSM/article/view/7322)]. Other research highlights how social media intensity (frequency and duration of time on social media) is a strong mediator in the relationship between materialism and negative consumption, suggesting that higher social media engagement is directly linked to increased impulsive, compulsive, and conspicuous purchasing [[3](https://pmc.ncbi.nlm.nih.gov/articles/PMC9096894/)]. One research paper reported a strong correlation between social media activity and consumer spending patterns of university students in Turkey, suggesting that social media significantly influences young consumers' purchasing decisions [[4](https://dergipark.org.tr/en/pub/ijsshs/issue/26218/276033)].
#
# The findings of this research has informed some of the demographic research questions I created for this analysis to better understand not just the relationship between social media and consumers, but the various backgrounds of the consumers themselves. These findings also confirmed some of my own beliefs about social media and consumption, which made me want to explore this topic further on my own and see what patterns arise.

# %% [markdown]
# # Methodology
# ### Analysis
# The dependent variable of my analysis is if social media influenced a purchase which in this dataset was a binary “yes” or “no” answer from the participant. The independent variables are all categorical instead of continuous (metrical, interval-scale). As a result, I intend to use [chi-quare tests of independence](https://www.jmp.com/en_us/statistics-knowledge-portal/chi-square-test/chi-square-test-of-independence.html) to evaluate the relationship between various demographic variables and consumer decision making. This method determines whether categorical variables are independent or related to each other which is ideal for the dataset I am using due to the categorical nature of the independent variables and the binary nature of the dependent variable.
#
# ### Presentation of Findings
# I plan to present my results in tables, calculations, and the output of the calculations (test statistics, chi-square distribution value, etc). This presentation method is appropriate for my analysis because the variables are either binary or categorical, which can be difficult to present graphically. However, bar charts may be an exception as I can show the distribution of, for example, the various income levels on the x-axis and the total number of respondents in each category whose purchases were influenced by social media on the y-axis. This may be beneficial to further understand the dataset and analysis by providing a visual component to the research in addition to tables of text and numbers.

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Before We Begin...
#
# __Important Note__: Due to the length of my analysis, I've decided to create a separate analysis file (``data_analysis.ipynb``). The file includes the entirety of my analysis. In this file, I will include my tables and the overarching calculations. If you're curious about how and why I did certain parts of my analysis, that information will be in the analysis file. During portions of my analysis here, I will include a "``In data_analysis file``:..." note along with an brief explanation of what I did before moving on into the analysis present here. If I were to include my entire data analysis here, you'd be scrolling for quite some time and I don't think that'd be very fun.
#
# Before we get started on the analysis, there are some terms and conditions I would like to discuss:
#
# <u>General Terminology</u>
# * ``P-value`` = "the probability of observing the data assuming the null hypothesis is true, helping to determine the strength of the evidence against the null hypothesis" ([geeksforgeeks](https://www.geeksforgeeks.org/python-pearsons-chi-square-test/)). The closer to 0 the p-value is, the [stronger the evidence against the null hypothesis](https://www.geo.fu-berlin.de/en/v/soga-r/Basics-of-statistics/Hypothesis-Tests/Introduction-to-Hypothesis-Testing/Critical-Value-and-the-p-Value-Approach/index.html#:~:text=The%20smaller%20(closer%20to%200,null%20hypothesis%20is%20not%20rejected.).
# * ``Null hypothesis`` = "a general statistical statement or assumption about a population parameter that is assumed to be true Until we have sufficient evidence to reject it. It is generally denoted by Ho"([geeksforgeeks](https://www.geeksforgeeks.org/python-pearsons-chi-square-test/)).
# * ``Alternate hypothesis`` = "considered as competing of the null hypothesis. It is generally denoted by H1 . The general goal of our hypothesis testing is to test the Alternative hypothesis against the null hypothesis" ([geeksforgeeks](https://www.geeksforgeeks.org/python-pearsons-chi-square-test/)).
#
# <u>General Conditions</u>
# * The ``null hypothesis`` for this study is that there _is no significant relation_ between the given factor and social media's influence on the consumer's purchase.
# * The ``alternative hypothesis`` for this study is that there _is a significant relation_ between the given factor and social media's influence on the consumer's purchase.
# * Based on [current practices](https://passel2.unl.edu/view/lesson/9beaa382bf7e/8), I will be using an alpha value of 5.0% ``(p < 0.05)`` to determine if observed deviations are significant.
#
# __Chi-Square Test of Independence__
#
# <u>Terminology</u>
# * ``Observed values`` = the actual data in the dataset
# * ``Expected values`` = the frequencies you'd anticipate seeing in each category if the null hypothesis is true
#
# <u>Conditions</u>
# * [An observed value can be zero](https://www.theanalysisfactor.com/observed-values-less-than-5-in-a-chi-square-test-no-biggie/) as long as the expected value for that cell is not zero. An expected value of zero can lead to undefined calculations.
# * There must be an [expected value of at least 5](https://www.jmp.com/en_us/statistics-knowledge-portal/chi-square-test/chi-square-test-of-independence.html) for each combination of variables, otherwise the test results are unreliable.
# * ``Expected values`` are calculated using this [function](https://www.geeksforgeeks.org/python-pearsons-chi-square-test/): (row total * column total) / grand total
# * If chi-square calculated value > chi-square critical value, then the [null hypothesis is rejected](https://passel2.unl.edu/view/lesson/9beaa382bf7e/8#:~:text=If%20your%20chi%2Dsquare%20calculated,to%20reject%22%20your%20null%20hypothesis.).

# %% [markdown]
# ### Packages for Analysis

# %%
import csv
import pandas as pd
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display,HTML
from PIL import Image

# %% [markdown]
# ``In RQ1_data_analysis file``: I converted the dataset csv file into a list of dictionaries and then ran a sanity check on the dataset to ensure each row was a unique consumer.

# %% [markdown]
# ### RQ1: What demographic factors have the strongest relationship with a consumer's purchase being influenced by social media?
# I will be analyzing four different demographic factors:
# 1. Age: age of consumer
# 2. Gender: gender of consumer
# 3. Income: annual income of consumer in USD
# 4. Education level: highest level of education attained by the consumer (e.g., Bachelor's, Master's, PhD, High School)
#
# _Note: The factor descriptions are from the dataset's data card on [Kaggle](https://www.kaggle.com/datasets/lastman0800/impact-of-social-media-dataset/data)._

# %% [markdown]
# <u>__Factor 1: Age__</u>

# %% [markdown]
# * ``Null Hypothesis``: Age and social media's influence on a purchase are independent.
# * ``Alternative Hypothesis``: Age and social media's influence on a purchase are not independent.

# %% [markdown]
# ``In RQ1_data_analysis file``:
# 1. Determined the range of ages present in the dataset (22-45 years old)
# 2. Split the ages into 2 groups (ages 22-33 and 34-45)
# 3. Calculated the totals of each range and how many in each range were influenced or not influenced by social media for a purchase (see contingency table below)
# 5. Table met conditions for chi-square test of independence and performed the test.

# %%
observed_age_plot = pd.read_csv('observed_age_table.csv')
observed_age_plot
# Out:
#                    ages 22-33  ages 34-45  row totals
# 0      influenced         254          32         286
# 1  not influenced          14          32          46
# 2   column totals         268          64         300

# %%
path="images/obs_vs_expected_age_graph.png" # image path

with Image.open(path) as i:
	display(i)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1428x882>

# %% [markdown]
# <u>Results from chi-square test</u>:
# * p-value = 7.921679253072971e-20
# * alpha = 0.05
#
# Since our p-value is less than our alpha (0.05), we reject the null hypothesis that age and social media influence has no significant relation. We can assume the differences between the expected and observed values could not be due to mere chance.
#
# <u>Insights from observed vs expected values</u>:
# * More consumers than expected aged 22-33 completed a purchase influenced by social media.
# * Fewer consumers than expected aged 22-23 were uninfluenced by social media during their purchase.
# * Fewer consumers than expected aged 34-45 completed a purchase influenced by social media.
# * More consumers than expected aged 34-45 were uninfluenced by social media during their purchase.

# %% [markdown]
# <u>__Factor 2: Gender__</u>

# %% [markdown]
# * ``Null Hypothesis``: Gender and social media's influence on a purchase are independent.
# * ``Alternative Hypothesis``: Gender and social media's influence on a purchase are not independent.

# %% [markdown]
# ``In RQ1_data_analysis file``:
# 1. Determined the gender labels present in the dataset (male, female, and nonbinary).
# 2. Calculated the totals of each combination of gender and social media influence ("influenced" or "uninfluenced").
# 3. Realized I couldn't use the chi-square test because the non-binary row and column totals created an expected value less than 5.
# 4. Decided to not include the ``non-binary`` consumer so I can use the chi-square test with a male/female and influenced/not influenced contingency table. I also reasoned this data point is "ok" to remove since it is the only non-binary instance recorded and therefore not representative of the greater population being studied.
# 5. After creating the revised contingency table to meet to conditions for performing the chi-square test, I performed the test.

# %%
observed_gender_plot = pd.read_csv('revised_observed_gender_table.csv')
observed_gender_plot
# Out:
#                 female  male  row totals
# influenced         137   149         286
# not influenced      12     1          13
# column totals      149   150         299

# %%
path="images/obs_vs_expected_gender_graph.png" # image path

with Image.open(path) as i:
	display(i)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1414x882>

# %% [markdown]
# <u>Results from chi-square test</u>:
# * p-value = 0.004397000976185477
# * alpha = 0.05
#
# Since our p-value is less than our alpha (0.05), we reject the null hypothesis that age and social media influence has no significant relation. We can assume the differences between the expected and observed values could not be due to mere chance.
#
# <u>Insights from observed vs expected values</u>:
# * Slightly less female consumers than expected completed a purchase influenced by social media.
# * Slightly more female consumers than expected were uninfluenced by social media during their purchase.
# * More male consumers than expected completed a purchase influenced by social media.
# * Fewer male consumers than expected were uninfluenced by social media during their purchase.

# %% [markdown]
# <u>__Factor 3: Income__</u>

# %% [markdown]
# * ``Null Hypothesis``: Income and social media's influence on a purchase are independent.
# * ``Alternative Hypothesis``: Income and social media's influence on a purchase are not independent.

# %% [markdown]
# ``In RQ1_data_analysis file``:
# 1. Determined the range of incomes present in the dataset (\\$32,000 to \$80,000).
# 2. Grouped the income levels based on on [2022 US Census Bureau](https://www.census.gov/content/dam/Census/library/publications/2023/demo/p60-279.pdf) household income data and [Yahoo!Finance's](https://finance.yahoo.com/news/income-fall-americas-lower-middle-122100515.html?guccounter=1&guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&guce_referrer_sig=AQAAAM6H35XwcgpCtSdjGKClh_A4Xn4KgA5u5USDoU498z-05vA5t7BvBlIZCrK3yCAJdVJ6baLY6QpOCoTlzevd_009j3xKVKC_fJcDvLe0qGdFohdOBI9_RxlE7DxOqaF9AwzM2ByIo00zFpXhuiTSKDjakxxlAJ14DBXJhf6BjbTb) income groupings and associated class labels:
#     * ``Lower class``: up to \$30,000
#     * ``Lower-middle class``: \\$30,001 - \$58,020
#     * ``Middle class``: \\$58,021 - \$94,000
#     * ``Upper-middle class``: \\$94,001 - \$153,000
#     * ``Upper class``: over \$153,000
#
# 4. Calculated the totals of each combination of income levels and social media influence on purchases ("influenced" or "uninfluenced"). Populated the contingency table with these calculations.
# 5. There were no expected values less than 5, so I performed the chi-square analysis with the data in the table.

# %%
observed_gender_plot = pd.read_csv('observed_income_table.csv')
observed_gender_plot
# Out:
#                 lower-middle class  middle class  row totals
# influenced                     189            97         286
# not influenced                  14             0          14
# column totals                  203            97         300

# %%
path="images/obs_vs_expected_income_graph.png" # image path

with Image.open(path) as i:
	display(i)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1408x908>

# %% [markdown]
# <u>Results from chi-square test</u>:
# * p-value = 0.01845367498420565
# * alpha = 0.05
#
# Since our p-value is less than our alpha (0.05), we reject the null hypothesis that income level and social media influence on a purchase has no significant relation. We can assume the differences between the expected and observed values could not be due to mere chance.
#
# <u>Insights from observed vs expected values</u>:
# * Slightly fewer lower-middle class consumers than expected were influenced by social media for a purchase.
# * Slightly more lower-middle class consumers than expected were not influenced by social media for a purchase.
# * More middle class consumers than expected were influenced by social media for a purchase.
# * Fewer middle class consumers than expected were not influecned by social media for a purchase.

# %% [markdown]
# <u>__Factor 5: Education Level__</u>

# %% [markdown]
# * ``Null Hypothesis``: Education level and social media's influence on a purchase are independent.
# * ``Alternative Hypothesis``: Education level and social media's influence on a purchase are not independent.

# %% [markdown]
# ``In RQ1_data_analysis file``:
# 1. Determined the levels of education present in the dataset (high school, bachelor's, master's, and phd).
# 2. Calculated the totals of each combination of education levels and social media influence on purchases ("influenced" or "uninfluenced"). Populated the contingency table with these calculations.
# 3. The combinations I originally created had two expected values that were less than 5 (high school/uninfluenced and PhD/uninfluenced combinations). This caused a dilemma when deciding how to reconfigure the combinations based on accuracy or precision of results.
#     * Dilemma: If I choose to not include high school educated and phd educated consumers, I would have more precise measurements for the education levels still included in the analysis. However I would lose accuracy because I'd be losing over a sixth (47 consumers aka about 16%) of the total consumer population in the dataset. If I chose to include high school educated and phd educated consumers, I'd have a higher accuracy in my analysis. However, I would lose some precision since I'd have to combine education levels together to ensure all ``expected values`` are greater than 5.
#     * Decision: I reasoned I would rather my measurements be more correct and accurate rather than precise. So, I am combined education levels together to create the categories: ``high school to bachelor's`` and ``master's to PhD``.
# 5. Revised my original education contingency table to reflect my decision.
# 6. The revised table met the conditions for the chi-square test, so I ran the test.

# %%
observed_edu_plot = pd.read_csv('revised_observed_edu_table.csv')
observed_edu_plot
# Out:
#                 High School to Bachelor's  Master's to PhD  row totals
# influenced                            167              119         286
# not influenced                         14               14          14
# column totals                         181              119         300

# %%
path="images/obs_vs_expected_edu_graph.png" # image path

with Image.open(path) as i:
	display(i)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1408x906>

# %% [markdown]
# <u>Results from chi-square test</u>:
# * p-value = 0.5110062497684047
# * alpha = 0.05
#
# Since our p-value is greater than our alpha (0.05), we accept the null hypothesis that income level and social media influence on a purchase has no significant relation. We cannot assume the differences between the expected and observed values could not be due to mere chance.
#
# <u>Insights from observed vs expected values</u>:
# * Slightly more consumers than expected with a high school to bachelor's education level were influenced by social media for a purchase.
# * Slightly less consumers than expected with a high school to bachelor's education level were not influenced by social media for a purchase.
# * Slightly less consumers than expected with a master's or phd education level were influenced by social media for a purchase.
# * Slightly more consumers than expected with a master's or phd education level were not influenced by social media for a purchase.

# %% [markdown]
# #### RQ2: What social media platforms are the most used by consumers whose purchases were influenced by social media?

# %% [markdown]
# ``In Analysis File``:
# * Determined what social media platforms consumers reported using in the dataset.
# * Calculated the counts for each combination of social media platform and social media influence.
# * Populated a contingency table with the counts.
# * Created a bar graph for better visualization of the results.

# %%
observed_edu_plot = pd.read_csv('observed_platforms_table.csv')
observed_edu_plot
# Out:
#                 LinkedIn  Twitter  Instagram  Pinterest  Snapchat  Facebook  \
# influenced            18       28         98         23        15        61
# not influenced         0        0          0          0         2         0
# column totals         18       28         98         23        17        61
#
#                 TikTok  row totals
# influenced          43         286
# not influenced      12          14
# column totals       55         300

# %%
path="images/social_media_platforms_graph.png" # image path

with Image.open(path) as i:
	display(i)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1402x890>

# %% [markdown]
# <u>Insights from contingency table & bar chart</u>:
#
# The top three social media platforms used by consumers who reported a purchase being influenced by social media are as follows:
# 1. Instagram (98 consumers out of 286 aka ~34.27%)
# 2. Facebook (61 consumers out of 286 aka ~21.33%)
# 3. TikTok (43 consumers out of 286 aka ~15.03%)

# %% [markdown]
# #### RQ3: Are there specific product categories where consumers are most likely to report that social media influenced their purchasing decisions?

# %% [markdown]
# ``In Analysis File``:
# * Determined what product categories consumers reported a purchase from in the dataset.
# * Calculated the counts for each combination of social media platform and social media influencing a purchase.
# * Populated a contingency table with the results.
# * Created a bar graph to visualize of the results.

# %%
observed_edu_plot = pd.read_csv('observed_categories_table.csv')
observed_edu_plot
# Out:
#                 Food  Fashion  Fitness  Beauty  Electronics  Home Decor  N/A  \
# influenced         1       50       40      50           79          65    1
# not influenced     0        0        0       0            0           0   14
# column totals      1       50       40      50           79          65   15
#
#                 row totals
# influenced             286
# not influenced          14
# column totals          300

# %%
path="images/product_categories_graph.png" # image path

with Image.open(path) as i:
	display(i)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1402x882>

# %% [markdown]
# <u>Insights from contingency table and bar chart</u>:
#
# The top four product categories of consumers whose purchase was influenced by social media are as follows:
# 1. Electronics (79 consumers out of 286 aka ~27.62%)
# 2. Home Decor (65 consumers out of 286 aka ~22.72%)
# 3. Fasion and Beauty (both 50 consumers out of 286 aka ~17.48%)

# %% [markdown]
# # Conclusion
# _Important Note: The outline for the conclusion section was generated by ChatGPT._
#
# This study set out to explore the relationship between social media usage and consumer purchasing behavior. In particular, the study focused on identifying the demographic factors that influence this relationship and aimed to understand the types of social media platforms and product categories most associated with social media’s influence on purchase decisions.
#
# ## Key Findings
# __Demographics and Social Media Influence on Purchase Decisions__:
#
# The analysis revealed that age, gender, and income have statistically significant relationships with whether a consumer’s purchasing decisions are influenced by social media. Specifically younger consumers (age 22 to 33), men, and those with higher income levels (\\$58,021 to \$94,000) had higher observed values compared to the calculated expected values for social media as a factor in their purchase decisions. In contrast, education level did not exhibit a significant relationship, though limitations in the analysis of this variable (see ``Limitations`` section below) may have affected these results.
#
# __Social Media Platforms and Influence__:
#
# Among the social media platforms, Instagram emerged as the most statistically significant platform in relation to social media’s influence on a consumer’s purchase. An estimated 34.27% of respondents reported Instagram as one of their most-used platforms and that their purchases were influenced by social media. Facebook (roughly 21.33%) and TikTok (roughly 15.03%) followed as the next most statistically significant platforms. These findings could suggest that visual-centric platforms like Instagram, Facebook and TikTok may have a stronger impact on consumer behavior, aligning with [existing literature](https://apmba.ub.ac.id/index.php/apmba/article/view/781) on the importance of visual appeal in social media marketing. This study’s findings also align with the [top social media platforms based on ad revenue](https://www.statista.com/statistics/1103339/social-media-ad-revenue-platform/) being reported to be Facebook as the highest with Instagram and then TikTok following after.
#
# __Product Categories and Social Media Influence__:
#
# The analysis of product categories revealed that electronics (27.62%), home decor (22.72%), and fashion/beauty (17.48%) were most frequently associated with social media-driven purchase decisions. This suggests that consumers are more likely to be influenced by social media when purchasing products that are visually appealing, trend-driven, or have strong brand identities, which is consistent with prior research emphasizing the role of social media in shaping consumer preferences for these categories ([electronics](https://www.nepjol.info/index.php/juem/article/download/70430/53714/205382), [home decor](https://www.statista.com/statistics/1016281/social-media-influence-on-home-decor-style-generation-us/), [fashion and beauty](https://www.researchgate.net/publication/378704036_Impact_of_Social_Media_on_Fashion_Trends_and_Consumer_Behavior_in_Kenya#:~:text=In%20developed%20economies%20like%20the,Kylie%20Jenner%20and%20Kim%20Kardashian)).
#
# ## Limitations
# The greatest limitation of my analysis was that the chi-square test can only conclude if there is or is not some relationship between two variables. However, [we cannot conclude that one variable _causes_ the other](https://www.jmp.com/en_us/statistics-knowledge-portal/chi-square-test/chi-square-test-of-independence.html).
#
# Another limitation was that groupings of data/combinations that had less than 5 expected values did not meet the conditions to perform a chi-square test. As a result, the specific combinations with expected values less than 5 either had to be removed from the contingency table or all combinations had to be reconfigured to ensure all groups’ expected values were above 5. This situation occurred during two portions of ``RQ1`` with gender and education levels analyses. For the gender analysis, I excluded the nonbinary consumer in the contingency table and reasoned that this data point is "ok" to remove since it is the only non-binary instance recorded and therefore not representative of the greater population being studied. For the education levels analysis, I combined education levels together to create the categories ``high school to bachelor's`` and ``master's to PhD`` to prioritize accuracy (at the expense of precision) and achieve expected values greater than 5.
#
# ## Critical Analysis & Implications
# This study's findings provide valuable insights into the intersection of social media and consumer behavior. The significant influence of demographic factors—particularly age, gender, and income—suggests that marketers could tailor their strategies to better target specific groups. For instance, brands looking to reach younger, higher-income individuals might prioritize platforms like Instagram, where these demographics are more engaged with social media content that influences their buying decisions.
#
# In practice, these findings can inform targeted advertising strategies. Given the dominance of Facebook, Instagram, and TikTok as key platforms for influencing purchases, businesses in product categories like fashion/beauty, electronics, and home decor may benefit from influencer marketing and visually compelling content on the platforms. Moreover, understanding the specific product categories that are most impacted by social media can help businesses refine their product offerings and promotional tactics to align with consumer interests.
#
# However, the research conducted here did encounter some important limitations. For instance, the relationship between education level and social media influence was not found to be significant, but this may be due to the methodological constraints. Future research could explore this variable in more detail by utilizing larger, more diverse datasets or by incorporating additional factors such as occupation or geographic location, which may offer deeper insights.
#
# ## Broader Impact & Future Research
# The findings of this research contributes to the growing body of literature centered around social media’s influence on consumer behavior. It also emphasizes the importance of demographic targeting and platform selection in digital marketing strategies.
#
# Overall, while the findings from this research provide useful insights into the current landscape of social media’s influence on consumer spending behavior, there remains much to explore in this domain. While this research mainly focused on the current, immediate influence of social media on consumer behavior, future research could explore more long-term impacts of social media when it comes to considerations such as consumer loyalty and repeat purchases. Future work could also dive into the effects of newer digital platforms like TikTok when it comes to influencing consumer behavior. Another avenue is to investigate how consumer spending behaviors may differ between social media platforms hosting in-app shopping interfaces versus links to external store sites. Overall, researchers and practitioners in social media marketing alike can potentially build on these findings to develop more effective, targeted strategies in rapidly evolving digital spaces.
